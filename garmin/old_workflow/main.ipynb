# %%
import pandas as pd
hikes = pd.read_csv('hikes.csv')
hikes
# Out:
#   Activity Type                 Date  Favorite             Title  Distance  \
# 0        Hiking  2026-01-15 08:53:55     False  Amecameca Hiking      5.05
#
#   Calories      Time  Avg HR  Max HR  Aerobic TE  ...  Body Battery Drain  \
# 0    1,482  02:57:08     136     180         3.2  ...                 -17
#
#    Min Temp Decompression Best Lap Time Number of Laps  Max Temp  Moving Time  \
# 0      68.0            No      02:57:08              1      84.2     01:56:43
#
#    Elapsed Time Min Elevation  Max Elevation
# 0      03:27:25        12,089         13,083
#
# [1 rows x 29 columns]

# %%
runs = pd.read_csv('runs.csv')
runs
# Out:
#        Activity Type                 Date  Favorite                     Title  \
# 0  Treadmill Running  2026-01-24 10:10:33     False         Treadmill Running
# 1  Treadmill Running  2026-01-21 18:40:35     False         Treadmill Running
# 2            Running  2026-01-18 17:47:03     False                   Running
# 3            Running  2026-01-14 09:03:48     False        Cuauhtémoc Running
# 4  Treadmill Running  2026-01-09 19:06:44     False         Treadmill Running
# 5            Running  2026-01-07 19:32:34     False           Chicago Running
# 6            Running  2026-01-05 18:09:42     False           Chicago Running
# 7            Running  2025-12-22 17:30:49     False  South Barrington Running
#
#    Distance  Calories        Time  Avg HR  Max HR  Aerobic TE  ...  \
# 0      3.04       383    00:31:02     148     166         3.0  ...
# 1      1.12       140    00:12:07     140     151         2.0  ...
# 2      0.87       135    00:10:04     156     190         2.5  ...
# 3      0.48        54  00:04:54.1     134     145         0.8  ...
# 4      1.52       215    00:18:09     143     162         2.3  ...
# 5      1.77       230    00:16:54     159     181         2.8  ...
# 6      2.15       225    00:21:30     135     177         2.4  ...
# 7      1.02       124    00:10:02     137     152         2.0  ...
#
#    Body Battery Drain  Min Temp Decompression Best Lap Time Number of Laps  \
# 0                 -10      71.6            No    00:00:24.2              4
# 1                  -2      80.6            No    00:01:14.8              2
# 2                  --      71.6            No      00:10:04              1
# 3                  -1      69.8            No    00:04:54.1              1
# 4                  -3      77.0            No    00:05:40.3              2
# 5                  -3      69.8            No    00:06:58.8              2
# 6                  -5      64.4            No    00:01:17.0              3
# 7                  -1      73.4            No    00:00:07.8              2
#
#   Max Temp  Moving Time  Elapsed Time  Min Elevation  Max Elevation
# 0     82.4     00:30:15      00:31:02             --             --
# 1     86.0     00:11:52      00:12:07             --             --
# 2     78.8     00:08:55      00:12:57          7,973          7,980
# 3     71.6     00:04:33    00:04:58.7          6,520          6,528
# 4     84.2     00:17:32      00:18:12             --             --
# 5     78.8     00:16:31      00:17:16            604            615
# 6     78.8     00:20:55      00:23:44            611            625
# 7     84.2     00:09:51      00:10:03            470            484
#
# [8 rows x 36 columns]

# %%
import pandas as pd

# -----------------------------
# Load Files
# -----------------------------
runs = pd.read_csv("runs.csv")
hikes = pd.read_csv("hikes.csv")
old_log = pd.read_csv("ultra50kmRuns.csv")  # your first training log CSV

# -----------------------------
# Helper: Clean Garmin Numeric Fields
# -----------------------------
def clean_numeric(series):
    return (
        series.astype(str)
        .str.replace(",", "", regex=False)
        .replace("--", None)
        .astype(float)
    )

# -----------------------------
# Clean RUNS data
# -----------------------------
runs["Distance"] = clean_numeric(runs["Distance"])
runs["Calories"] = clean_numeric(runs["Calories"])
runs["Total Ascent"] = clean_numeric(runs["Total Ascent"])
runs["Total Descent"] = clean_numeric(runs["Total Descent"])
runs["Avg HR"] = clean_numeric(runs["Avg HR"])
runs["Max HR"] = clean_numeric(runs["Max HR"])

# -----------------------------
# Clean HIKES data
# -----------------------------
hikes["Distance"] = clean_numeric(hikes["Distance"])
hikes["Calories"] = clean_numeric(hikes["Calories"])
hikes["Ascent"] = clean_numeric(hikes["Ascent"])
hikes["Total Descent"] = clean_numeric(hikes["Total Descent"])
hikes["Avg HR"] = clean_numeric(hikes["Avg HR"])
hikes["Max HR"] = clean_numeric(hikes["Max HR"])

# -----------------------------
# Convert RUNS → Target Schema
# -----------------------------
runs_out = pd.DataFrame({
    "Date": pd.to_datetime(runs["Date"]).dt.date,
    "Distance": runs["Distance"],
    "TotalTime": runs["Time"],
    "MovingTime": runs["Moving Time"],
    "AveragePace": runs["Avg Pace"],
    "AverageMovingPace": runs["Avg Pace"],
    "ElevationGain": runs["Total Ascent"].fillna(0),
    "ElevationDescent": runs["Total Descent"].fillna(0),
    "TerrainType": runs["Activity Type"].apply(
        lambda x: "Treadmill" if "Treadmill" in x else "Track" if "Track" in x else "Road"
    ),
    "RunType": "Easy",
    "AvgHeartRate": runs["Avg HR"],
    "MaxHeartRate": runs["Max HR"],
    "CaloriesBurnt": runs["Calories"],
    "EstimatedSweatLoss": None,
    "Felt": None,
    "LegFatigue": None,
    "Notes": None
})

# -----------------------------
# Convert HIKES → Target Schema
# -----------------------------
hikes_out = pd.DataFrame({
    "Date": pd.to_datetime(hikes["Date"]).dt.date,
    "Distance": hikes["Distance"],
    "TotalTime": hikes["Time"],
    "MovingTime": hikes["Moving Time"],
    "AveragePace": hikes["Avg Pace"],
    "AverageMovingPace": hikes["Avg Pace"],
    "ElevationGain": hikes["Ascent"],
    "ElevationDescent": hikes["Total Descent"],
    "TerrainType": "Trail",
    "RunType": "Hike",  # <-- as requested
    "AvgHeartRate": hikes["Avg HR"],
    "MaxHeartRate": hikes["Max HR"],
    "CaloriesBurnt": hikes["Calories"],
    "EstimatedSweatLoss": None,
    "Felt": None,
    "LegFatigue": None,
    "Notes": None
})

# -----------------------------
# Combine New Activities
# -----------------------------
combined = pd.concat([runs_out, hikes_out], ignore_index=True)

# -----------------------------
# Bring in Old Notes
# -----------------------------
old_log["Date"] = pd.to_datetime(old_log["Date"]).dt.date

notes_lookup = old_log[["Date", "Distance", "Notes"]]

combined = combined.merge(
    notes_lookup,
    on=["Date", "Distance"],
    how="left",
    suffixes=("", "_old")
)

# Fill Notes from old log where available
combined["Notes"] = combined["Notes_old"].combine_first(combined["Notes"])
combined.drop(columns=["Notes_old"], inplace=True)

# -----------------------------
# Final Sort + Export
# -----------------------------
final_df = combined.sort_values("Date")

final_df.to_csv("log.csv", index=False)

# print("✅ Training log updated and saved as ultra_training_log_updated.csv")
# print(final_df.head())
final_df
# Out:
#           Date  Distance   TotalTime  MovingTime AveragePace  \
# 10  2025-12-22      1.02    00:10:02    00:09:51        9:53
# 9   2026-01-05      2.15    00:21:30    00:20:55        9:59
# 8   2026-01-07      1.77    00:16:54    00:16:31        9:33
# 7   2026-01-09      1.52    00:18:09    00:17:32       11:56
# 6   2026-01-14      0.48  00:04:54.1    00:04:33       10:10
# 11  2026-01-15      5.05    02:57:08    01:56:43       35:04
# 5   2026-01-18      0.87    00:10:04    00:08:55       11:31
# 4   2026-01-21      1.12    00:12:07    00:11:52       10:47
# 3   2026-01-24      3.04    00:31:02    00:30:15       10:13
# 2   2026-01-25      1.36    00:13:14    00:13:09        9:42
# 1   2026-01-27   4910.00    00:30:27    00:29:53        9:59
# 0   2026-01-28   1610.00  00:09:58.7  00:09:39.9        9:58
#
#    AverageMovingPace  ElevationGain  ElevationDescent TerrainType RunType  \
# 10              9:53           16.0              13.0        Road    Easy
# 9               9:59            0.0               0.0        Road    Easy
# 8               9:33           16.0              13.0        Road    Easy
# 7              11:56            0.0               0.0   Treadmill    Easy
# 6              10:10            0.0               3.0        Road    Easy
# 11             35:04         1083.0             948.0       Trail    Hike
# 5              11:31            3.0               3.0        Road    Easy
# 4              10:47            0.0               0.0   Treadmill    Easy
# 3              10:13            0.0               0.0   Treadmill    Easy
# 2               9:42            3.0              10.0        Road    Easy
# 1               9:59            3.0              16.0       Track    Easy
# 0               9:58            0.0               0.0       Track    Easy
#
#     AvgHeartRate  MaxHeartRate  CaloriesBurnt EstimatedSweatLoss  Felt  \
# 10         137.0         152.0          124.0               None  None
# 9          135.0         177.0          225.0               None  None
# 8          159.0         181.0          230.0               None  None
# 7          143.0         162.0          215.0               None  None
# 6          134.0         145.0           54.0               None  None
# 11         136.0         180.0         1482.0               None  None
# 5          156.0         190.0          135.0               None  None
# 4          140.0         151.0          140.0               None  None
# 3          148.0         166.0          383.0               None  None
# 2          163.0         191.0          186.0               None  None
# 1          143.0         198.0          354.0               None  None
# 0          153.0         179.0          134.0               None  None
#
#    LegFatigue                                              Notes
# 10       None  First run of my training for my first 50km rac...
# 9        None  Tried to run for 30 minutes but only did 22 be...
# 8        None  Ran to a restaurant where I hung out with Pric...
# 7        None  Did a full body workout and decided to get a l...
# 6        None  Very short run to meet my mom at a Breakfast s...
# 11       None  5mile hike. Was my first ever hike at 3800 met...
# 5        None  Very short run. This was my final run in Mexic...
# 4        None  First official day of training where I will be...
# 3        None                                               None
# 2        None                                               None
# 1        None                                               None
# 0        None                                               None

# %%
import pandas as pd
df =pd.read_csv('log.csv')
df.to_json('ultra50km.json', orient='records')
df
# Out:
#           Date  Distance   TotalTime MovingTime AveragePace AverageMovingPace  \
# 0   2025-12-22      1.02    00:10:02   00:09:51        9:53              9:53
# 1   2026-01-05      2.15    00:21:30   00:20:55        9:59              9:59
# 2   2026-01-07      1.77    00:16:54   00:16:31        9:33              9:33
# 3   2026-01-09      1.52    00:18:09   00:17:32       11:56             11:56
# 4   2026-01-14      0.48  00:04:54.1   00:04:33       10:10             10:10
# 5   2026-01-15      5.05    02:57:08   01:56:43       35:04             35:04
# 6   2026-01-18      0.87    00:10:04   00:08:55       11:31             11:31
# 7   2026-01-21      1.12    00:12:07   00:11:52       10:47             10:47
# 8   2026-01-24      3.04    00:31:02   00:30:15       10:13             10:13
# 9   2026-01-25      1.36    00:13:14   00:13:09        9:42              9:42
# 10  2026-01-27      3.05    00:30:27   00:29:53        9:59              9:59
# 11  2026-01-28      1.00  00:09:58.7   00:09:39        9:58              9:58
#
#     ElevationGain  ElevationDescent TerrainType RunType  AvgHeartRate  \
# 0            16.0              13.0        Road    Easy         137.0
# 1             0.0               0.0        Road    Easy         135.0
# 2            16.0              13.0        Road    Easy         159.0
# 3             0.0               0.0   Treadmill    Easy         143.0
# 4             0.0               3.0        Road    Easy         134.0
# 5          1083.0             948.0       Trail    Hike         136.0
# 6             3.0               3.0        Road    Easy         156.0
# 7             0.0               0.0   Treadmill    Easy         140.0
# 8             0.0               0.0   Treadmill    Easy         148.0
# 9             3.0              10.0        Road    Easy         163.0
# 10            3.0              16.0       Track    Easy         143.0
# 11            0.0               0.0       Track    Easy         153.0
#
#     MaxHeartRate  CaloriesBurnt  EstimatedSweatLoss  Felt  LegFatigue  \
# 0          152.0          124.0                 NaN   NaN         NaN
# 1          177.0          225.0                 NaN   NaN         NaN
# 2          181.0          230.0                 NaN   NaN         NaN
# 3          162.0          215.0                 NaN   NaN         NaN
# 4          145.0           54.0                 NaN   NaN         NaN
# 5          180.0         1482.0                 NaN   NaN         NaN
# 6          190.0          135.0                 NaN   NaN         NaN
# 7          151.0          140.0                 NaN   NaN         NaN
# 8          166.0          383.0                 NaN   NaN         NaN
# 9          191.0          186.0                 NaN   NaN         NaN
# 10         198.0          354.0                 NaN   NaN         NaN
# 11         179.0          134.0                 NaN   NaN         NaN
#
#                                                 Notes
# 0   First run of my training for my first 50km rac...
# 1   Tried to run for 30 minutes but only did 22 be...
# 2   Ran to a restaurant where I hung out with Pric...
# 3   Did a full body workout and decided to get a l...
# 4   Very short run to meet my mom at a Breakfast s...
# 5   5mile hike. Was my first ever hike at 3800 met...
# 6   Very short run. This was my final run in Mexic...
# 7   First official day of training where I will be...
# 8   Wanted to run for 30 minutes nonstop at a easy...
# 9   Ran to Miles and Keitlin's apartment to watch ...
# 10  Ran for 30 minutes on the depaul track at a ve...
# 11  Hit legs and did a one mile run on the track. ...
