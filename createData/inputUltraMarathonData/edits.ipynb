# %%
import pandas as pd

# %%
# df = pd.read_csv('runs.csv')
# df = df[['Date', 'Distance', 'Time', 'AveragePace', 'Notes']]
# # df.to_csv('runs2.csv')
# df['RunGoal'] = 'Madison Marathon 11-9-2025'
# df.to_csv('runs3.csv', index=False)

# %%
# import pandas as pd
# pd.read_csv('runs3.csv').to_json('runs.json', orient='records')

# %%
# For Ultramarathon 50 km data analysis
import pandas as pd
df =pd.read_csv('ultra50kmRuns.csv')
df.to_json('ultra50km.json', orient='records')
df
# Out:
#          Date  Distance TotalTime MovingTime AveragePace AverageMovingPace  \
# 0  2025-12-22      1.02  00:10:02   00:09:52        9:53              9:42
# 1  2026-01-05      2.15  00:21:30   00:20:55        9:59              9:43
# 2  2026-01-07      1.77  00:16:54   00:16:31        9:33              9:20
# 3  2026-01-09      1.52  00:18:09   00:17:32       11:56             11:32
# 4  2026-01-14      0.48  00:04:54   00:04:33       10:10              9:26
# 5  2026-01-15      5.05  02:57:08   01:56:43       35:04             23:06
# 6  2026-01-18      0.87  00:10:04   00:08:55       11:31             10:12
# 7  2026-01-21      1.12  00:12:07   00:11:52       10:47             10:33
#
#    ElevationGain  ElevationDescent TerrainType RunType  AvgHeartRate  \
# 0             16                13        Road    Easy           137
# 1              0                 0        Road    Easy           135
# 2             16                13        Road    Easy           159
# ...

# %%
df.iloc[0].to_list()
# Out:
# ['9:53',
#  '9:42',
#  np.int64(16),
#  np.int64(13),
#  'Road',
#  'Easy',
#  np.int64(137),
#  np.int64(152),
#  np.int64(124),
#  np.int64(166),
#  np.int64(4),
#  np.int64(1),
#  'First run of my training for my first 50km race. Very excited for the training that is ahead as I become the best mental and physical version of myself. ']

# %%
df.columns.to_list()
# Out:
# ['Date',
#  'Distance',
#  'Time',
#  'AveragePace',
#  'ElevationGain',
#  'TerrainType',
#  'RunType',
#  'AvgHeartRate',
#  'MaxHeartRate',
#  'Calories',
#  'Felt',
#  'LegFatigue',
#  'Notes']

# %%
df.index.to_list()
# Out:
# [('2025-12-22', 1.02, '00:10:02', '00:09:52')]
