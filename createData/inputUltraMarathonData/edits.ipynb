# %%
import pandas as pd

# %%
df = pd.read_csv('runs.csv')
df = df[['Date', 'Distance', 'Time', 'AveragePace', 'Notes']]
# df.to_csv('runs2.csv')
df['RunGoal'] = 'Madison Marathon 11-9-2025'
df.to_csv('runs3.csv', index=False)

# %%
import pandas as pd
pd.read_csv('runs3.csv').to_json('runs.json', orient='records')

# %%
# For Ultramarathon 50 km data analysis
df =pd.read_csv('ultra50kmRuns.csv')
df.to_json('ultra50km.json', orient='records')

# %%
# Out:
#                                    Date Distance  Time  AveragePace  \
# 2025-12-22 1.02 00:10:02 00:09:52  9:53     9:42    16           13
#
#                                   ElevationGain TerrainType  RunType  \
# 2025-12-22 1.02 00:10:02 00:09:52          Road        Easy      137
#
#                                    AvgHeartRate  MaxHeartRate  Calories  Felt  \
# 2025-12-22 1.02 00:10:02 00:09:52           152           124       166     4
#
#                                    LegFatigue  \
# 2025-12-22 1.02 00:10:02 00:09:52           1
#
#                                                                                Notes
# 2025-12-22 1.02 00:10:02 00:09:52  First run of my training for my first 50km rac...
